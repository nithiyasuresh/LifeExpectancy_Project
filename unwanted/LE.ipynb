# %%
# %config Completer.use_jedi = False

# %%
import pandas as pd
import csv
from sqlalchemy import create_engine, Integer, String, Float

# from config import *
# %config Completer.use_jedi = False

# %%
csv_file = "Life Expectancy Data.csv"
life_expectancy_df = pd.read_csv(csv_file)
life_expectancy_df.reset_index()
life_expectancy_df.head()
# Out:
#        Country  Year      Status  Life Expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant Deaths  Alcohol  Percentage Expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
life_expectancy_df = life_expectancy_df[["Country","Year","Life Expectancy","Adult Mortality","BMI","GDP","Population","Polio","HIV/AIDS"]]
life_expectancy_df
# Out:
#           Country  Year  Life Expectancy  Adult Mortality   BMI         GDP  \
# 0     Afghanistan  2015             65.0            263.0  19.1  584.259210
# 1     Afghanistan  2014             59.9            271.0  18.6  612.696514
# 2     Afghanistan  2013             59.9            268.0  18.1  631.744976
# 3     Afghanistan  2012             59.5            272.0  17.6  669.959000
# 4     Afghanistan  2011             59.2            275.0  17.2   63.537231
# ...           ...   ...              ...              ...   ...         ...
# 2933     Zimbabwe  2004             44.3            723.0  27.1  454.366654
# 2934     Zimbabwe  2003             44.5            715.0  26.7  453.351155
# 2935     Zimbabwe  2002             44.8             73.0  26.3   57.348340
# 2936     Zimbabwe  2001             45.3            686.0  25.9  548.587312
# 2937     Zimbabwe  2000             46.0            665.0  25.5  547.358879
#
#       Population  Polio  HIV/AIDS
# ...

# %%
life_clean_df = life_expectancy_df.sort_values(by=["Country","Year"])
life_clean_df.reset_index(drop=True)
# Out:
#           Country  Year  Life Expectancy  Adult Mortality   BMI         GDP  \
# 0     Afghanistan  2000             54.8            321.0  12.2  114.560000
# 1     Afghanistan  2001             55.3            316.0  12.6  117.496980
# 2     Afghanistan  2002             56.2              3.0  13.0  187.845950
# 3     Afghanistan  2003             56.7            295.0  13.4  198.728544
# 4     Afghanistan  2004             57.0            293.0  13.8  219.141353
# ...           ...   ...              ...              ...   ...         ...
# 2933     Zimbabwe  2011             54.9            464.0  29.9  839.927936
# 2934     Zimbabwe  2012             56.6            429.0   3.3  955.648466
# 2935     Zimbabwe  2013             58.0            399.0   3.8  111.227396
# 2936     Zimbabwe  2014             59.2            371.0  31.3  127.474620
# 2937     Zimbabwe  2015             67.0            336.0  31.8  118.693830
#
#       Population  Polio  HIV/AIDS
# ...

# %%
rds_connection_string = "{}:{}@localhost:5432/Life_Expectancy".format(username,password)

engine = create_engine(f'postgresql://{rds_connection_string}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7d5a4875b8ba> in <module>
# ----> 1 rds_connection_string = "{}:{}@localhost:5432/Life_Expectancy".format(username,password)
#       2
#       3 engine = create_engine(f'postgresql://{rds_connection_string}')
#
# NameError: name 'username' is not defined
