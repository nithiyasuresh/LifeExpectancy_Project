# %%
import pandas as pd
import csv
from sqlalchemy import create_engine, Integer, String, Float

# from config import *
# %config Completer.use_jedi = False

# %%
csv_file = "Life Expectancy Data.csv"
life_expectancy_df = pd.read_csv(csv_file, index_col=0)
life_expectancy_df.head()
# Out:
#              Year      Status  Life expectancy   Adult Mortality  \
# Country
# Afghanistan  2015  Developing              65.0            263.0
# Afghanistan  2014  Developing              59.9            271.0
# Afghanistan  2013  Developing              59.9            268.0
# Afghanistan  2012  Developing              59.5            272.0
# Afghanistan  2011  Developing              59.2            275.0
#
#              infant deaths  Alcohol  percentage expenditure  Hepatitis B  \
# Country
# Afghanistan             62     0.01               71.279624         65.0
# Afghanistan             64     0.01               73.523582         62.0
# Afghanistan             66     0.01               73.219243         64.0
# Afghanistan             69     0.01               78.184215         67.0
# Afghanistan             71     0.01                7.097109         68.0
#
#              Measles    BMI   ...  Polio  Total expenditure  Diphtheria   \
# Country                       ...
# ...

# %%
life_expectancy_new_df = life_expectancy_df.drop("infant deaths", axis=0)
life_expactancy_new_df

# df.drop(['column_nameA', 'column_nameB'], axis=1, inplace=True)

# df = df.drop("Max",axis=0)

# del life_expectancy_df["Alcohol"]
# life_expectancy_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-3b7f8dce39a6> in <module>
# ----> 1 life_expectancy_new_df = life_expectancy_df.drop("infant deaths", axis=0)
#       2 life_expactancy_new_df
#       3
#       4 # df.drop(['column_nameA', 'column_nameB'], axis=1, inplace=True)
#       5
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# ...

# %%
# print(life_expectancy_df.columns)
life_expectancy_df.describe()

# %%
# columns = ["Country","Year","Adult Mortality","Population","GDP","BMI","Life expectancy"]
# life_expectancy_df = life_expectancy_df.reindex(columns=columns)
# life_expectancy_df[columns] = life_expectancy_df[columns]
# life_expectancy_df[columns] = life_expectancy_df
# life_expectancy_df
